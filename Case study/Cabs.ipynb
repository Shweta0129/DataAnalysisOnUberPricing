# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cabs = pd.read_csv('/Users/yashgupta/Downloads/cabs_edited.csv')

# %%
cabs
# Out:
#      distance cab_type    time_stamp    destination            source  price  \
# 0        0.44     Lyft  1.544950e+12  North Station  Haymarket Square    5.0
# 1        0.44     Lyft  1.543280e+12  North Station  Haymarket Square   11.0
# 2        0.44     Lyft  1.543370e+12  North Station  Haymarket Square    7.0
# 3        0.44     Lyft  1.543550e+12  North Station  Haymarket Square   26.0
# 4        0.44     Lyft  1.543460e+12  North Station  Haymarket Square    9.0
# ..        ...      ...           ...            ...               ...    ...
# 149      2.36     Lyft  1.543250e+12         Fenway       Beacon Hill    7.0
# 150      2.32     Uber  1.545110e+12      North End          Back Bay   14.0
# 151      2.32     Uber  1.543640e+12      North End          Back Bay   20.5
# 152      2.32     Uber  1.545130e+12      North End          Back Bay    9.5
# 153      2.32     Uber  1.545070e+12      North End          Back Bay    9.5
#
# ...

# %%
cabs.columns
# Out:
# Index(['distance', 'cab_type', 'time_stamp', 'destination', 'source', 'price',
#        'surge_multiplier', 'id', 'product_id', 'name'],
#       dtype='object')

# %%
cabs_2 = cabs[['distance','price','name']]

# %%
cabs_2.max()
# Out:
# distance    3.61
# price       38.5
# name         WAV
# dtype: object

# %%
cabs_2.min()
# Out:
# distance     0.44
# price         3.0
# name        Black
# dtype: object

# %%
cabs_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154 entries, 0 to 153
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   distance  154 non-null    float64
#  1   price     141 non-null    float64
#  2   name      154 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 3.7+ KB

# %%
d = cabs_2.iloc[0:20]['distance']
x = cabs_2.iloc[0:20]['price']
plt.figure(figsize=(16,8), dpi=300)
plt.scatter(x,d,label = 'xyz')
